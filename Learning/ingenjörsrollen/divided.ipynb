# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
y_data = [102, 108, 124, 156, 210, 292, 408, 564]
x = range(len(y_data))
y = [102 + 3*x + 2*x**2 + x**3 for x in x]
ax.plot(x,y)
ax.scatter(x, y_data)
#ax.plot(x, y_data)
